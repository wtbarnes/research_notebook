# %% [markdown]
# # `hercules` HYDRAD helper package testing
#
# Test some of the plotting functionality of our `hercules` package.

# %%
from imp import reload
import os,sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn.apionly as sns
# %matplotlib inline
# Out:
# /opt/anaconda3/lib/python3.4/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
sys.path.append(os.path.join(os.environ['RESEARCH_DIR'],'hercules/hercules'))
import quick_look as ql
reload(ql)
# Out:
# <module 'quick_look' from '/home/wtb2/Documents/hercules/hercules/quick_look.py'>

# %%
htest = ql.QuickViewer('/data/datadrive2/HYDRAD_runs/hp1_hydrad_runs/electron/HYDRAD_20/Results/',figsize=(18,13),fontsize=22)

# %%
htest.load_results()

# %%
htest.make_timeseries(lower_percent=0.4,upper_percent=0.4)

# %%
htest.plot_profile(line_cm='Spectral',indices=[105])

# %%
htest.plot_timeseries()
