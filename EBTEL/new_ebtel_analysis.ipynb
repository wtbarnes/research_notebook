# %% [markdown]
# #Revised EBTEL Analysis Scripts

# %% [markdown]
# Testing reorganized EBTEL analysis scripts as well as addition of new features.

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
sys.path.append('/home/wtb2/Documents/EBTEL_analysis/src/')
import ebtel_dem as ebd
import ebtel_plot_em as ebpe
from imp import reload
reload(ebd)
reload(ebpe)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/__init__.py:1175: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# /usr/lib/python3/dist-packages/matplotlib/__init__.py:1175: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# <module 'ebtel_plot_em' from '/home/wtb2/Documents/EBTEL_analysis/src/ebtel_plot_em.py'>

# %% [markdown]
# First, set some basic parameters regarding what data set we want to load in.

# %%
root_dir = '/data/datadrive2/EBTEL-2fluid_runs/'
species = 'electron'
tpulse = 100.0
alpha = 1.5
loop_length = 40.0
solver = 'rka4'
Tn = np.arange(250,5250,250)

# %% [markdown]
# Now, instantiate the DEMProcess class and import data and compute statistics.

# %%
process = ebd.DEMProcess(root_dir,species,alpha,loop_length,tpulse,solver,verbose=True)

# %%
process.import_raw(Tn)
# Out:
# Unable to process file for Tn = 250, run = 44
# Unable to process file for Tn = 250, run = 45
# Unable to process file for Tn = 250, run = 46
# Unable to process file for Tn = 250, run = 47
# Unable to process file for Tn = 250, run = 48
# Unable to process file for Tn = 250, run = 49
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 500, run = 75
# Unable to process file for Tn = 500, run = 76
# Unable to process file for Tn = 500, run = 77
# Unable to process file for Tn = 500, run = 78
# Unable to process file for Tn = 500, run = 79
# Unable to process file for Tn = 500, run = 80
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 750, run = 106
# Unable to process file for Tn = 750, run = 107
# Unable to process file for Tn = 750, run = 108
# Unable to process file for Tn = 750, run = 109
# Unable to process file for Tn = 750, run = 110
# Unable to process file for Tn = 750, run = 111
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 1000, run = 137
# Unable to process file for Tn = 1000, run = 138
# Unable to process file for Tn = 1000, run = 139
# Unable to process file for Tn = 1000, run = 140
# Unable to process file for Tn = 1000, run = 141
# Unable to process file for Tn = 1000, run = 142
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 1250, run = 167
# Unable to process file for Tn = 1250, run = 168
# Unable to process file for Tn = 1250, run = 169
# Unable to process file for Tn = 1250, run = 170
# Unable to process file for Tn = 1250, run = 171
# Unable to process file for Tn = 1250, run = 172
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 1500, run = 200
# Unable to process file for Tn = 1500, run = 201
# Unable to process file for Tn = 1500, run = 202
# Unable to process file for Tn = 1500, run = 203
# Unable to process file for Tn = 1500, run = 204
# Unable to process file for Tn = 1500, run = 205
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 1750, run = 228
# Unable to process file for Tn = 1750, run = 229
# Unable to process file for Tn = 1750, run = 230
# Unable to process file for Tn = 1750, run = 231
# Unable to process file for Tn = 1750, run = 232
# Unable to process file for Tn = 1750, run = 233
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 2000, run = 257
# Unable to process file for Tn = 2000, run = 258
# Unable to process file for Tn = 2000, run = 259
# Unable to process file for Tn = 2000, run = 260
# Unable to process file for Tn = 2000, run = 261
# Unable to process file for Tn = 2000, run = 262
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 2250, run = 286
# Unable to process file for Tn = 2250, run = 287
# Unable to process file for Tn = 2250, run = 288
# Unable to process file for Tn = 2250, run = 289
# Unable to process file for Tn = 2250, run = 290
# Unable to process file for Tn = 2250, run = 291
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 2500, run = 323
# Unable to process file for Tn = 2500, run = 324
# Unable to process file for Tn = 2500, run = 325
# Unable to process file for Tn = 2500, run = 326
# Unable to process file for Tn = 2500, run = 327
# Unable to process file for Tn = 2500, run = 328
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 2750, run = 345
# Unable to process file for Tn = 2750, run = 346
# Unable to process file for Tn = 2750, run = 347
# Unable to process file for Tn = 2750, run = 348
# Unable to process file for Tn = 2750, run = 349
# Unable to process file for Tn = 2750, run = 350
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 3000, run = 385
# Unable to process file for Tn = 3000, run = 386
# Unable to process file for Tn = 3000, run = 387
# Unable to process file for Tn = 3000, run = 388
# Unable to process file for Tn = 3000, run = 389
# Unable to process file for Tn = 3000, run = 390
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 3250, run = 417
# Unable to process file for Tn = 3250, run = 418
# Unable to process file for Tn = 3250, run = 419
# Unable to process file for Tn = 3250, run = 420
# Unable to process file for Tn = 3250, run = 421
# Unable to process file for Tn = 3250, run = 422
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 3500, run = 435
# Unable to process file for Tn = 3500, run = 436
# Unable to process file for Tn = 3500, run = 437
# Unable to process file for Tn = 3500, run = 438
# Unable to process file for Tn = 3500, run = 439
# Unable to process file for Tn = 3500, run = 440
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 3750, run = 477
# Unable to process file for Tn = 3750, run = 478
# Unable to process file for Tn = 3750, run = 479
# Unable to process file for Tn = 3750, run = 480
# Unable to process file for Tn = 3750, run = 481
# Unable to process file for Tn = 3750, run = 482
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 4000, run = 500
# Unable to process file for Tn = 4000, run = 501
# Unable to process file for Tn = 4000, run = 502
# Unable to process file for Tn = 4000, run = 503
# Unable to process file for Tn = 4000, run = 504
# Unable to process file for Tn = 4000, run = 505
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 4250, run = 527
# Unable to process file for Tn = 4250, run = 528
# Unable to process file for Tn = 4250, run = 529
# Unable to process file for Tn = 4250, run = 530
# Unable to process file for Tn = 4250, run = 531
# Unable to process file for Tn = 4250, run = 532
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 4500, run = 556
# Unable to process file for Tn = 4500, run = 557
# Unable to process file for Tn = 4500, run = 558
# Unable to process file for Tn = 4500, run = 559
# Unable to process file for Tn = 4500, run = 560
# Unable to process file for Tn = 4500, run = 561
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 4750, run = 589
# Unable to process file for Tn = 4750, run = 590
# Unable to process file for Tn = 4750, run = 591
# Unable to process file for Tn = 4750, run = 592
# Unable to process file for Tn = 4750, run = 593
# Unable to process file for Tn = 4750, run = 594
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %
# Unable to process file for Tn = 5000, run = 625
# Unable to process file for Tn = 5000, run = 626
# Unable to process file for Tn = 5000, run = 627
# Unable to process file for Tn = 5000, run = 628
# Unable to process file for Tn = 5000, run = 629
# Unable to process file for Tn = 5000, run = 630
# Reached end of list or too many missing files.
# Estimated percentage of files read = 100.000000 %

# %%
process.calc_stats()

# %% [markdown]
# Next, instantiate the Analyze class and feed it the processed $\mathrm{EM}$ and $T$ arrays.

# %%
slope_limits = {'cool_lower':6.0,'cool_upper':6.6,'hot_lower':6.8,'hot_upper':7.3}
analyze = ebd.DEMAnalyze(process.em,process.temp_em,process.em_mean,process.temp_mean,process.em_std,
                         verbose=True,slope_limits=slope_limits,fit_method='fit_all',lim_method='dynamic',
                        max_percent_drop=0.92,delta_t=0.5)

# %%
analyze.interp_and_filter()
analyze.many_fits()
# Out:
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.96618809405 K
# T_hot_lower = 6.46618809405 K
# Cool bound out of range, T = 6.34 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.47
# Hot bound out of range, T = 7.09 < T_limit = 6.97
# or T_lower_limit = 6.47 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.96618809405 K
# T_hot_lower = 6.46618809405 K
# Cool bound out of range, T = 6.34 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.47
# Hot bound out of range, T = 7.09 < T_limit = 6.97
# or T_lower_limit = 6.47 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.96618809405 K
# T_hot_lower = 6.46618809405 K
# Cool bound out of range, T = 6.34 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.47
# Hot bound out of range, T = 7.09 < T_limit = 6.97
# or T_lower_limit = 6.47 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.96618809405 K
# T_hot_lower = 6.46618809405 K
# Cool bound out of range, T = 6.34 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.47
# Hot bound out of range, T = 7.09 < T_limit = 6.97
# or T_lower_limit = 6.47 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.96618809405 K
# T_hot_lower = 6.46618809405 K
# Cool bound out of range, T = 6.34 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.47
# Hot bound out of range, T = 7.09 < T_limit = 6.97
# or T_lower_limit = 6.47 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.96618809405 K
# T_hot_lower = 6.46618809405 K
# Cool bound out of range, T = 6.34 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.47
# Hot bound out of range, T = 7.09 < T_limit = 6.97
# or T_lower_limit = 6.47 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.96618809405 K
# T_hot_lower = 6.46618809405 K
# Cool bound out of range, T = 6.34 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.47
# Hot bound out of range, T = 7.09 < T_limit = 6.97
# or T_lower_limit = 6.47 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.96618809405 K
# T_hot_lower = 6.46618809405 K
# Cool bound out of range, T = 6.34 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.47
# Hot bound out of range, T = 7.09 < T_limit = 6.97
# or T_lower_limit = 6.47 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.9467883942 K
# T_hot_lower = 6.4467883942 K
# Cool bound out of range, T = 6.41 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.09 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.9467883942 K
# T_hot_lower = 6.4467883942 K
# Cool bound out of range, T = 6.41 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.09 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.9467883942 K
# T_hot_lower = 6.4467883942 K
# Cool bound out of range, T = 6.41 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.09 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.9467883942 K
# T_hot_lower = 6.4467883942 K
# Cool bound out of range, T = 6.41 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.09 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.9467883942 K
# T_hot_lower = 6.4467883942 K
# Cool bound out of range, T = 6.41 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.09 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.9467883942 K
# T_hot_lower = 6.4467883942 K
# Cool bound out of range, T = 6.41 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.09 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.9467883942 K
# T_hot_lower = 6.4467883942 K
# Cool bound out of range, T = 6.41 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.09 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.9467883942 K
# T_hot_lower = 6.4467883942 K
# Cool bound out of range, T = 6.41 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.09 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95485242621 K
# T_hot_lower = 6.45485242621 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95485242621 K
# T_hot_lower = 6.45485242621 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95485242621 K
# T_hot_lower = 6.45485242621 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95485242621 K
# T_hot_lower = 6.45485242621 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95485242621 K
# T_hot_lower = 6.45485242621 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95485242621 K
# T_hot_lower = 6.45485242621 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95485242621 K
# T_hot_lower = 6.45485242621 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95485242621 K
# T_hot_lower = 6.45485242621 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95310155078 K
# T_hot_lower = 6.45310155078 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95310155078 K
# T_hot_lower = 6.45310155078 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95310155078 K
# T_hot_lower = 6.45310155078 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95310155078 K
# T_hot_lower = 6.45310155078 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95310155078 K
# T_hot_lower = 6.45310155078 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95310155078 K
# T_hot_lower = 6.45310155078 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95310155078 K
# T_hot_lower = 6.45310155078 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95310155078 K
# T_hot_lower = 6.45310155078 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.03 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.94977488744 K
# T_hot_lower = 6.44977488744 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.10 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.94977488744 K
# T_hot_lower = 6.44977488744 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.10 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.94977488744 K
# T_hot_lower = 6.44977488744 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.10 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.94977488744 K
# T_hot_lower = 6.44977488744 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.10 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.94977488744 K
# T_hot_lower = 6.44977488744 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.10 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.94977488744 K
# T_hot_lower = 6.44977488744 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.10 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.94977488744 K
# T_hot_lower = 6.44977488744 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.10 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.94977488744 K
# T_hot_lower = 6.44977488744 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.45
# Hot bound out of range, T = 7.10 < T_limit = 6.95
# or T_lower_limit = 6.45 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.96071535768 K
# T_hot_lower = 6.46071535768 K
# Cool bound out of range, T = 6.41 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.46
# Hot bound out of range, T = 7.07 < T_limit = 6.96
# or T_lower_limit = 6.46 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.96071535768 K
# T_hot_lower = 6.46071535768 K
# Cool bound out of range, T = 6.41 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.46
# Hot bound out of range, T = 7.07 < T_limit = 6.96
# or T_lower_limit = 6.46 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.93860430215 K
# T_hot_lower = 6.43860430215 K
# Cool bound out of range, T = 6.40 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.44
# Hot bound out of range, T = 7.03 < T_limit = 6.94
# or T_lower_limit = 6.44 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95590295148 K
# T_hot_lower = 6.45590295148 K
# Cool bound out of range, T = 6.39 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.46
# Hot bound out of range, T = 7.05 < T_limit = 6.96
# or T_lower_limit = 6.46 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03395697849 K
# T_hot_lower = 6.53395697849 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.12 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03395697849 K
# T_hot_lower = 6.53395697849 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.12 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.02706353177 K
# T_hot_lower = 6.52706353177 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.16 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.02706353177 K
# T_hot_lower = 6.52706353177 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.16 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.05113556778 K
# T_hot_lower = 6.55113556778 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.10 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.05113556778 K
# T_hot_lower = 6.55113556778 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.10 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.05113556778 K
# T_hot_lower = 6.55113556778 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.10 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.05113556778 K
# T_hot_lower = 6.55113556778 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.10 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.05113556778 K
# T_hot_lower = 6.55113556778 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.10 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04259629815 K
# T_hot_lower = 6.54259629815 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.13 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04259629815 K
# T_hot_lower = 6.54259629815 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.13 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04259629815 K
# T_hot_lower = 6.54259629815 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.13 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04259629815 K
# T_hot_lower = 6.54259629815 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.13 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.06671335668 K
# T_hot_lower = 6.56671335668 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.57
# Hot bound out of range, T = 7.16 < T_limit = 7.07
# or T_lower_limit = 6.57 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.06671335668 K
# T_hot_lower = 6.56671335668 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.57
# Hot bound out of range, T = 7.16 < T_limit = 7.07
# or T_lower_limit = 6.57 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03426713357 K
# T_hot_lower = 6.53426713357 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.12 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03426713357 K
# T_hot_lower = 6.53426713357 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.12 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03426713357 K
# T_hot_lower = 6.53426713357 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.12 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04669834917 K
# T_hot_lower = 6.54669834917 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.23 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04669834917 K
# T_hot_lower = 6.54669834917 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.23 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03787893947 K
# T_hot_lower = 6.53787893947 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.12 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03787893947 K
# T_hot_lower = 6.53787893947 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.12 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.05996498249 K
# T_hot_lower = 6.55996498249 K
# Cool bound out of range, T = 6.33 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.56
# Hot bound out of range, T = 7.13 < T_limit = 7.06
# or T_lower_limit = 6.56 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.05996498249 K
# T_hot_lower = 6.55996498249 K
# Cool bound out of range, T = 6.33 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.56
# Hot bound out of range, T = 7.13 < T_limit = 7.06
# or T_lower_limit = 6.56 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.05996498249 K
# T_hot_lower = 6.55996498249 K
# Cool bound out of range, T = 6.33 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.56
# Hot bound out of range, T = 7.13 < T_limit = 7.06
# or T_lower_limit = 6.56 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04114557279 K
# T_hot_lower = 6.54114557279 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.15 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04114557279 K
# T_hot_lower = 6.54114557279 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.15 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04114557279 K
# T_hot_lower = 6.54114557279 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.15 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.06098549275 K
# T_hot_lower = 6.56098549275 K
# Cool bound out of range, T = 6.33 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.56
# Hot bound out of range, T = 7.15 < T_limit = 7.06
# or T_lower_limit = 6.56 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04114557279 K
# T_hot_lower = 6.54114557279 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.15 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04114557279 K
# T_hot_lower = 6.54114557279 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.15 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04114557279 K
# T_hot_lower = 6.54114557279 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.15 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04114557279 K
# T_hot_lower = 6.54114557279 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.15 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04114557279 K
# T_hot_lower = 6.54114557279 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.15 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04981990995 K
# T_hot_lower = 6.54981990995 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.23 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04981990995 K
# T_hot_lower = 6.54981990995 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.23 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04981990995 K
# T_hot_lower = 6.54981990995 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.23 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04981990995 K
# T_hot_lower = 6.54981990995 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.23 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04981990995 K
# T_hot_lower = 6.54981990995 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.23 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04981990995 K
# T_hot_lower = 6.54981990995 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.23 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04981990995 K
# T_hot_lower = 6.54981990995 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.23 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04981990995 K
# T_hot_lower = 6.54981990995 K
# Cool bound out of range, T = 6.36 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.23 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03434217109 K
# T_hot_lower = 6.53434217109 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.15 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03434217109 K
# T_hot_lower = 6.53434217109 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.15 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03434217109 K
# T_hot_lower = 6.53434217109 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.15 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03434217109 K
# T_hot_lower = 6.53434217109 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.15 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03434217109 K
# T_hot_lower = 6.53434217109 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.15 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03434217109 K
# T_hot_lower = 6.53434217109 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.15 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03434217109 K
# T_hot_lower = 6.53434217109 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.15 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03434217109 K
# T_hot_lower = 6.53434217109 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.15 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03451725863 K
# T_hot_lower = 6.53451725863 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.11 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03451725863 K
# T_hot_lower = 6.53451725863 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.11 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03451725863 K
# T_hot_lower = 6.53451725863 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.11 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03451725863 K
# T_hot_lower = 6.53451725863 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.11 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03451725863 K
# T_hot_lower = 6.53451725863 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.11 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03451725863 K
# T_hot_lower = 6.53451725863 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.11 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03451725863 K
# T_hot_lower = 6.53451725863 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.11 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.03451725863 K
# T_hot_lower = 6.53451725863 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.53
# Hot bound out of range, T = 7.11 < T_limit = 7.03
# or T_lower_limit = 6.53 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04536768384 K
# T_hot_lower = 6.54536768384 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.11 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04536768384 K
# T_hot_lower = 6.54536768384 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.11 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04536768384 K
# T_hot_lower = 6.54536768384 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.11 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04536768384 K
# T_hot_lower = 6.54536768384 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.11 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04536768384 K
# T_hot_lower = 6.54536768384 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.11 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04536768384 K
# T_hot_lower = 6.54536768384 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.11 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04536768384 K
# T_hot_lower = 6.54536768384 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.11 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04536768384 K
# T_hot_lower = 6.54536768384 K
# Cool bound out of range, T = 6.35 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.55
# Hot bound out of range, T = 7.11 < T_limit = 7.05
# or T_lower_limit = 6.55 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.06299649825 K
# T_hot_lower = 6.56299649825 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.56
# Hot bound out of range, T = 7.11 < T_limit = 7.06
# or T_lower_limit = 6.56 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.06299649825 K
# T_hot_lower = 6.56299649825 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.56
# Hot bound out of range, T = 7.11 < T_limit = 7.06
# or T_lower_limit = 6.56 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.06299649825 K
# T_hot_lower = 6.56299649825 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.56
# Hot bound out of range, T = 7.11 < T_limit = 7.06
# or T_lower_limit = 6.56 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.06299649825 K
# T_hot_lower = 6.56299649825 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.56
# Hot bound out of range, T = 7.11 < T_limit = 7.06
# or T_lower_limit = 6.56 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.06299649825 K
# T_hot_lower = 6.56299649825 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.56
# Hot bound out of range, T = 7.11 < T_limit = 7.06
# or T_lower_limit = 6.56 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.06299649825 K
# T_hot_lower = 6.56299649825 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.56
# Hot bound out of range, T = 7.11 < T_limit = 7.06
# or T_lower_limit = 6.56 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.06299649825 K
# T_hot_lower = 6.56299649825 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.56
# Hot bound out of range, T = 7.11 < T_limit = 7.06
# or T_lower_limit = 6.56 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.06299649825 K
# T_hot_lower = 6.56299649825 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.56
# Hot bound out of range, T = 7.11 < T_limit = 7.06
# or T_lower_limit = 6.56 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04005002501 K
# T_hot_lower = 6.54005002501 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.54
# Hot bound out of range, T = 7.11 < T_limit = 7.04
# or T_lower_limit = 6.54 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11990995498 K
# T_hot_lower = 6.61990995498 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.62
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11990995498 K
# T_hot_lower = 6.61990995498 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.62
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11990995498 K
# T_hot_lower = 6.61990995498 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.62
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11990995498 K
# T_hot_lower = 6.61990995498 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.62
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11990995498 K
# T_hot_lower = 6.61990995498 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.62
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11990995498 K
# T_hot_lower = 6.61990995498 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.62
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11990995498 K
# T_hot_lower = 6.61990995498 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.62
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10746373187 K
# T_hot_lower = 6.60746373187 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10746373187 K
# T_hot_lower = 6.60746373187 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10746373187 K
# T_hot_lower = 6.60746373187 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10746373187 K
# T_hot_lower = 6.60746373187 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10746373187 K
# T_hot_lower = 6.60746373187 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10746373187 K
# T_hot_lower = 6.60746373187 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10746373187 K
# T_hot_lower = 6.60746373187 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10746373187 K
# T_hot_lower = 6.60746373187 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.13672336168 K
# T_hot_lower = 6.63672336168 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.64
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.13672336168 K
# T_hot_lower = 6.63672336168 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.64
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.13672336168 K
# T_hot_lower = 6.63672336168 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.64
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.13672336168 K
# T_hot_lower = 6.63672336168 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.64
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.13672336168 K
# T_hot_lower = 6.63672336168 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.64
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.13672336168 K
# T_hot_lower = 6.63672336168 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.64
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.13672336168 K
# T_hot_lower = 6.63672336168 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.64
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.13672336168 K
# T_hot_lower = 6.63672336168 K
# Cool bound out of range, T = 6.29 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.64
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12596298149 K
# T_hot_lower = 6.62596298149 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12596298149 K
# T_hot_lower = 6.62596298149 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12596298149 K
# T_hot_lower = 6.62596298149 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12596298149 K
# T_hot_lower = 6.62596298149 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12596298149 K
# T_hot_lower = 6.62596298149 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12596298149 K
# T_hot_lower = 6.62596298149 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12596298149 K
# T_hot_lower = 6.62596298149 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12596298149 K
# T_hot_lower = 6.62596298149 K
# Cool bound out of range, T = 6.30 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11262631316 K
# T_hot_lower = 6.61262631316 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11262631316 K
# T_hot_lower = 6.61262631316 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11262631316 K
# T_hot_lower = 6.61262631316 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11262631316 K
# T_hot_lower = 6.61262631316 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11262631316 K
# T_hot_lower = 6.61262631316 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11262631316 K
# T_hot_lower = 6.61262631316 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11262631316 K
# T_hot_lower = 6.61262631316 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11262631316 K
# T_hot_lower = 6.61262631316 K
# Cool bound out of range, T = 6.27 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10609304652 K
# T_hot_lower = 6.60609304652 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10609304652 K
# T_hot_lower = 6.60609304652 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10609304652 K
# T_hot_lower = 6.60609304652 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10609304652 K
# T_hot_lower = 6.60609304652 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10609304652 K
# T_hot_lower = 6.60609304652 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10609304652 K
# T_hot_lower = 6.60609304652 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10609304652 K
# T_hot_lower = 6.60609304652 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.10609304652 K
# T_hot_lower = 6.60609304652 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.61
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.09906453227 K
# T_hot_lower = 6.59906453227 K
# Cool bound out of range, T = 6.33 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.60
# Hot bound out of range, T = 7.21 < T_limit = 7.10
# or T_lower_limit = 6.60 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.09906453227 K
# T_hot_lower = 6.59906453227 K
# Cool bound out of range, T = 6.33 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.60
# Hot bound out of range, T = 7.21 < T_limit = 7.10
# or T_lower_limit = 6.60 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.09906453227 K
# T_hot_lower = 6.59906453227 K
# Cool bound out of range, T = 6.33 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.60
# Hot bound out of range, T = 7.21 < T_limit = 7.10
# or T_lower_limit = 6.60 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.09906453227 K
# T_hot_lower = 6.59906453227 K
# Cool bound out of range, T = 6.33 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.60
# Hot bound out of range, T = 7.21 < T_limit = 7.10
# or T_lower_limit = 6.60 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.09906453227 K
# T_hot_lower = 6.59906453227 K
# Cool bound out of range, T = 6.33 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.60
# Hot bound out of range, T = 7.21 < T_limit = 7.10
# or T_lower_limit = 6.60 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.09906453227 K
# T_hot_lower = 6.59906453227 K
# Cool bound out of range, T = 6.33 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.60
# Hot bound out of range, T = 7.21 < T_limit = 7.10
# or T_lower_limit = 6.60 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.09906453227 K
# T_hot_lower = 6.59906453227 K
# Cool bound out of range, T = 6.33 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.60
# Hot bound out of range, T = 7.21 < T_limit = 7.10
# or T_lower_limit = 6.60 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.09906453227 K
# T_hot_lower = 6.59906453227 K
# Cool bound out of range, T = 6.33 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.60
# Hot bound out of range, T = 7.21 < T_limit = 7.10
# or T_lower_limit = 6.60 < T_max = 6.60
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12682341171 K
# T_hot_lower = 6.62682341171 K
# Cool bound out of range, T = 6.28 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12682341171 K
# T_hot_lower = 6.62682341171 K
# Cool bound out of range, T = 6.28 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12682341171 K
# T_hot_lower = 6.62682341171 K
# Cool bound out of range, T = 6.28 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12682341171 K
# T_hot_lower = 6.62682341171 K
# Cool bound out of range, T = 6.28 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12682341171 K
# T_hot_lower = 6.62682341171 K
# Cool bound out of range, T = 6.28 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12682341171 K
# T_hot_lower = 6.62682341171 K
# Cool bound out of range, T = 6.28 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12682341171 K
# T_hot_lower = 6.62682341171 K
# Cool bound out of range, T = 6.28 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12682341171 K
# T_hot_lower = 6.62682341171 K
# Cool bound out of range, T = 6.28 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12556778389 K
# T_hot_lower = 6.62556778389 K
# Cool bound out of range, T = 6.24 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12556778389 K
# T_hot_lower = 6.62556778389 K
# Cool bound out of range, T = 6.24 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12556778389 K
# T_hot_lower = 6.62556778389 K
# Cool bound out of range, T = 6.24 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12556778389 K
# T_hot_lower = 6.62556778389 K
# Cool bound out of range, T = 6.24 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12556778389 K
# T_hot_lower = 6.62556778389 K
# Cool bound out of range, T = 6.24 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12556778389 K
# T_hot_lower = 6.62556778389 K
# Cool bound out of range, T = 6.24 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12556778389 K
# T_hot_lower = 6.62556778389 K
# Cool bound out of range, T = 6.24 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.12556778389 K
# T_hot_lower = 6.62556778389 K
# Cool bound out of range, T = 6.24 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.13208604302 K
# T_hot_lower = 6.63208604302 K
# Cool bound out of range, T = 6.32 > T_limit = 6.00
# or T_upper_limit = 6.60 > T_max = 6.63
# T_cool_upper = 6.6 K
# ...
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42966483242 K
# T_hot_lower = 6.92966483242 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42966483242 K
# T_hot_lower = 6.92966483242 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42966483242 K
# T_hot_lower = 6.92966483242 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42966483242 K
# T_hot_lower = 6.92966483242 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42966483242 K
# T_hot_lower = 6.92966483242 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46984492246 K
# T_hot_lower = 6.96984492246 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46984492246 K
# T_hot_lower = 6.96984492246 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46984492246 K
# T_hot_lower = 6.96984492246 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46984492246 K
# T_hot_lower = 6.96984492246 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46984492246 K
# T_hot_lower = 6.96984492246 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46984492246 K
# T_hot_lower = 6.96984492246 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46984492246 K
# T_hot_lower = 6.96984492246 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46984492246 K
# T_hot_lower = 6.96984492246 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.45458229115 K
# T_hot_lower = 6.95458229115 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.45458229115 K
# T_hot_lower = 6.95458229115 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.45458229115 K
# T_hot_lower = 6.95458229115 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.45458229115 K
# T_hot_lower = 6.95458229115 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.45458229115 K
# T_hot_lower = 6.95458229115 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.45458229115 K
# T_hot_lower = 6.95458229115 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.45458229115 K
# T_hot_lower = 6.95458229115 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.45458229115 K
# T_hot_lower = 6.95458229115 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46018509255 K
# T_hot_lower = 6.96018509255 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42813906953 K
# T_hot_lower = 6.92813906953 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42813906953 K
# T_hot_lower = 6.92813906953 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42813906953 K
# T_hot_lower = 6.92813906953 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42813906953 K
# T_hot_lower = 6.92813906953 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42813906953 K
# T_hot_lower = 6.92813906953 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42813906953 K
# T_hot_lower = 6.92813906953 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42813906953 K
# T_hot_lower = 6.92813906953 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42813906953 K
# T_hot_lower = 6.92813906953 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.44020010005 K
# T_hot_lower = 6.94020010005 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.43687343672 K
# T_hot_lower = 6.93687343672 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.44020010005 K
# T_hot_lower = 6.94020010005 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.44020010005 K
# T_hot_lower = 6.94020010005 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.44020010005 K
# T_hot_lower = 6.94020010005 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47747373687 K
# T_hot_lower = 6.97747373687 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.44020010005 K
# T_hot_lower = 6.94020010005 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47747373687 K
# T_hot_lower = 6.97747373687 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47747373687 K
# T_hot_lower = 6.97747373687 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42286143072 K
# T_hot_lower = 6.92286143072 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42286143072 K
# T_hot_lower = 6.92286143072 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42286143072 K
# T_hot_lower = 6.92286143072 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42286143072 K
# T_hot_lower = 6.92286143072 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42286143072 K
# T_hot_lower = 6.92286143072 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42286143072 K
# T_hot_lower = 6.92286143072 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42286143072 K
# T_hot_lower = 6.92286143072 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42286143072 K
# T_hot_lower = 6.92286143072 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46666333167 K
# T_hot_lower = 6.96666333167 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.48690345173 K
# T_hot_lower = 6.98690345173 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46666333167 K
# T_hot_lower = 6.96666333167 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46666333167 K
# T_hot_lower = 6.96666333167 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.48690345173 K
# T_hot_lower = 6.98690345173 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.48690345173 K
# T_hot_lower = 6.98690345173 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.48690345173 K
# T_hot_lower = 6.98690345173 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.48690345173 K
# T_hot_lower = 6.98690345173 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.38139069535 K
# T_hot_lower = 6.88139069535 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.38139069535 K
# T_hot_lower = 6.88139069535 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.38139069535 K
# T_hot_lower = 6.88139069535 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.38139069535 K
# T_hot_lower = 6.88139069535 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.41493246623 K
# T_hot_lower = 6.91493246623 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.41493246623 K
# T_hot_lower = 6.91493246623 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.41493246623 K
# T_hot_lower = 6.91493246623 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.41493246623 K
# T_hot_lower = 6.91493246623 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47785392696 K
# T_hot_lower = 6.97785392696 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47785392696 K
# T_hot_lower = 6.97785392696 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47785392696 K
# T_hot_lower = 6.97785392696 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47785392696 K
# T_hot_lower = 6.97785392696 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47785392696 K
# T_hot_lower = 6.97785392696 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47785392696 K
# T_hot_lower = 6.97785392696 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47785392696 K
# T_hot_lower = 6.97785392696 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.45722361181 K
# T_hot_lower = 6.95722361181 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47785392696 K
# T_hot_lower = 6.97785392696 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40262631316 K
# T_hot_lower = 6.90262631316 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40262631316 K
# T_hot_lower = 6.90262631316 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40262631316 K
# T_hot_lower = 6.90262631316 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40262631316 K
# T_hot_lower = 6.90262631316 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40262631316 K
# T_hot_lower = 6.90262631316 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40262631316 K
# T_hot_lower = 6.90262631316 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40262631316 K
# T_hot_lower = 6.90262631316 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40262631316 K
# T_hot_lower = 6.90262631316 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.45785392696 K
# T_hot_lower = 6.95785392696 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.48347173587 K
# T_hot_lower = 6.98347173587 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.48347173587 K
# T_hot_lower = 6.98347173587 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.48347173587 K
# T_hot_lower = 6.98347173587 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.48347173587 K
# T_hot_lower = 6.98347173587 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.48347173587 K
# T_hot_lower = 6.98347173587 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.48347173587 K
# T_hot_lower = 6.98347173587 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.48347173587 K
# T_hot_lower = 6.98347173587 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47756878439 K
# T_hot_lower = 6.97756878439 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47756878439 K
# T_hot_lower = 6.97756878439 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47756878439 K
# T_hot_lower = 6.97756878439 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47756878439 K
# T_hot_lower = 6.97756878439 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47756878439 K
# T_hot_lower = 6.97756878439 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47756878439 K
# T_hot_lower = 6.97756878439 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47756878439 K
# T_hot_lower = 6.97756878439 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.47756878439 K
# T_hot_lower = 6.97756878439 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4752076038 K
# T_hot_lower = 6.9752076038 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4752076038 K
# T_hot_lower = 6.9752076038 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4752076038 K
# T_hot_lower = 6.9752076038 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4752076038 K
# T_hot_lower = 6.9752076038 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4752076038 K
# T_hot_lower = 6.9752076038 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4752076038 K
# T_hot_lower = 6.9752076038 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4752076038 K
# T_hot_lower = 6.9752076038 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4752076038 K
# T_hot_lower = 6.9752076038 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.44170085043 K
# T_hot_lower = 6.94170085043 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.44170085043 K
# T_hot_lower = 6.94170085043 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.44170085043 K
# T_hot_lower = 6.94170085043 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.44170085043 K
# T_hot_lower = 6.94170085043 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.44170085043 K
# T_hot_lower = 6.94170085043 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46309154577 K
# T_hot_lower = 6.96309154577 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46309154577 K
# T_hot_lower = 6.96309154577 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46309154577 K
# T_hot_lower = 6.96309154577 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46613306653 K
# T_hot_lower = 6.96613306653 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46613306653 K
# T_hot_lower = 6.96613306653 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46613306653 K
# T_hot_lower = 6.96613306653 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46613306653 K
# T_hot_lower = 6.96613306653 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46613306653 K
# T_hot_lower = 6.96613306653 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46613306653 K
# T_hot_lower = 6.96613306653 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46613306653 K
# T_hot_lower = 6.96613306653 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46613306653 K
# T_hot_lower = 6.96613306653 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46104052026 K
# T_hot_lower = 6.96104052026 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46104052026 K
# T_hot_lower = 6.96104052026 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46104052026 K
# T_hot_lower = 6.96104052026 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46104052026 K
# T_hot_lower = 6.96104052026 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46104052026 K
# T_hot_lower = 6.96104052026 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46104052026 K
# T_hot_lower = 6.96104052026 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46104052026 K
# T_hot_lower = 6.96104052026 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46104052026 K
# T_hot_lower = 6.96104052026 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40677838919 K
# T_hot_lower = 6.90677838919 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40677838919 K
# T_hot_lower = 6.90677838919 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40677838919 K
# T_hot_lower = 6.90677838919 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40677838919 K
# T_hot_lower = 6.90677838919 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40677838919 K
# T_hot_lower = 6.90677838919 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40677838919 K
# T_hot_lower = 6.90677838919 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40677838919 K
# T_hot_lower = 6.90677838919 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40677838919 K
# T_hot_lower = 6.90677838919 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4383941971 K
# T_hot_lower = 6.9383941971 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4383941971 K
# T_hot_lower = 6.9383941971 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4383941971 K
# T_hot_lower = 6.9383941971 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4383941971 K
# T_hot_lower = 6.9383941971 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4383941971 K
# T_hot_lower = 6.9383941971 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4383941971 K
# T_hot_lower = 6.9383941971 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4383941971 K
# T_hot_lower = 6.9383941971 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4383941971 K
# T_hot_lower = 6.9383941971 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40250625313 K
# T_hot_lower = 6.90250625313 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40250625313 K
# T_hot_lower = 6.90250625313 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40250625313 K
# T_hot_lower = 6.90250625313 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40250625313 K
# T_hot_lower = 6.90250625313 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40250625313 K
# T_hot_lower = 6.90250625313 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40250625313 K
# T_hot_lower = 6.90250625313 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40250625313 K
# T_hot_lower = 6.90250625313 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40250625313 K
# T_hot_lower = 6.90250625313 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.46595297649 K
# T_hot_lower = 6.96595297649 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4763881941 K
# T_hot_lower = 6.9763881941 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4763881941 K
# T_hot_lower = 6.9763881941 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4763881941 K
# T_hot_lower = 6.9763881941 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.4763881941 K
# T_hot_lower = 6.9763881941 K

# %% [markdown]
# Next, we'll build our fit line parameter dictionaries so we can plot the fit lines on top of our emission curves.

# %%
t_cool = []
t_hot = []
for i in range(len(analyze.hot_fits)):
    sl = analyze.fit_limits(analyze.temp_mean[i],analyze.em_mean[i])
    t_cool.append(np.linspace(sl['cool_lower'],sl['cool_upper'],100))
    t_hot.append(np.linspace(sl['hot_lower'],sl['hot_upper'],100))
    
fit_lines = {'t_cool':t_cool,'t_hot':t_hot}
# Out:
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 6.95310155078 K
# T_hot_lower = 6.45310155078 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.04444722361 K
# T_hot_lower = 6.54444722361 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.11606803402 K
# T_hot_lower = 6.61606803402 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.16532766383 K
# T_hot_lower = 6.66532766383 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.21442721361 K
# T_hot_lower = 6.71442721361 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.23967983992 K
# T_hot_lower = 6.73967983992 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.28551775888 K
# T_hot_lower = 6.78551775888 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.30374687344 K
# T_hot_lower = 6.80374687344 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.33897948974 K
# T_hot_lower = 6.83897948974 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.35794397199 K
# T_hot_lower = 6.85794397199 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.35549274637 K
# T_hot_lower = 6.85549274637 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.34894947474 K
# T_hot_lower = 6.84894947474 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.37323661831 K
# T_hot_lower = 6.87323661831 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.38822411206 K
# T_hot_lower = 6.88822411206 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.39512756378 K
# T_hot_lower = 6.89512756378 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.39282641321 K
# T_hot_lower = 6.89282641321 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.41821910955 K
# T_hot_lower = 6.91821910955 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.40777388694 K
# T_hot_lower = 6.90777388694 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42054027014 K
# T_hot_lower = 6.92054027014 K
# T_cool_upper = 6.6 K
# T_cool_lower = 6.0 K
# T_hot_upper = 7.42866433217 K
# T_hot_lower = 6.92866433217 K

# %% [markdown]
# Now, plot the emission curves with superimposed fit lines and fit line slopes

# %%
plotter = ebpe.DEMPlotter(process.temp_em,process.em,process.temp_mean,process.em_mean,process.em_std,analyze.cool_fits,analyze.hot_fits)

# %%
plotter.plot_em_curves(fit_lines=fit_lines)

# %%
plotter.plot_em_slopes()

# %% [markdown]
# Something strange is going on with the fit uncertainty. Let's go back and calculate sigma from the original parameters and compare this to the new sigma value.

# %%
old_sigma = []
old_mean_temp = []
for i in range(len(process.em)):
    old_sigma.append(np.std(process.em[i],axis=0))
    old_mean_temp.append(np.mean(process.temp_em[i],axis=0))
# Out:
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:98: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)

# %%
i = 0
fig,axes = plt.subplots(5,4,figsize=(15,15),sharex=True,sharey=True)
plt.subplots_adjust(hspace=0,wspace=0)
for ax in axes.flatten():
    ax.plot(old_mean_temp[i],old_sigma[i],'ok',markersize=5)
    ax.plot(process.temp_mean[i],process.em_std[i],'--r',linewidth=2)
    ax.set_xticks([5.5,6.5,7.5])
    ax.set_xlim([5.5,7.5])
    ax.set_ylim([0,1])
    i = i + 1

# %% [markdown]
# So the interpolated $\sigma$ values follow the original $\sigma$ values quite closely, except for low values of $T_N$ where we don't have any valueable fit information anyway.

# %% [markdown]
# ##Computing $d\log{\mathrm{EM}}/d\log{T}$

# %% [markdown]
# Now, instead of performing a linear fit to separate branches of the $\mathrm{EM}$ curve, we will compute the derivative over the entire range of $T$.

# %%
def central_difference(x,y):
    dx = np.gradient(x)
    return np.gradient(y,dx)

# %%
d_EMd_T = []
for i in range(len(process.em_mean)):
    d_EMd_T.append(central_difference(process.temp_mean[i],process.em_mean[i]))

# %% [markdown]
# Now, we'll plot these values versus temperature.

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.gca()
for i in range(len(d_EMd_T)):
    ax.plot(process.temp_mean[i][:-50],d_EMd_T[i][:-50])
ax.axvline(linestyle='--',color='k',x=6.0)
ax.axvline(linestyle='--',color='k',x=6.6)
ax.axvline(linestyle='--',color='k',x=6.8)
ax.axvline(linestyle='--',color='k',x=7.3)
ax.set_xlim([5.5,7.5])
ax.set_ylim([-10,5])
ax.set_xlabel(r'$\log{T}$',fontsize=22)
ax.set_ylabel(r'$d\log{\mathrm{EM}}/d\log{T}$',fontsize=22)
plt.show()

# %% [markdown]
# Need to come up with a way of truncating the mess at the end. Right now, I'm just choosing to exclude the last 50 points of the interpolated emission measures; be more systematic about this.
